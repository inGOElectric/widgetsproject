# %%
import mysql.connector
import os
import zipfile
import pandas as pd
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
zip_file_path = r"C:\Users\Aparna\Downloads\whiteactiva\whiteactiva_355172104292980.zip"
output_directory = r"C:\Users\Aparna\Downloads\whiteactiva\whiteactiva_355172104292980"

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(output_directory)
extracted_files = os.listdir(output_directory)

db_config = {
    "host": "database-1.cbjabnlglbz6.ap-south-1.rds.amazonaws.com",
    "user": "admin",
    "password": "ingo4321",
    "database": "ingodata"
}

db_connection = mysql.connector.connect(**db_config)
cursor = db_connection.cursor()
mysql_engine = create_engine("mysql+mysqlconnector://admin:ingo4321@database-1.cbjabnlglbz6.ap-south-1.rds.amazonaws.com/ingodata")

for file_name in os.listdir(output_directory):
    if file_name.endswith('.xlsx'):
        filename = "_".join(file_name.split("_")[:-1])
        print(filename)
        table_name = os.path.splitext(filename)[0][:60]
        
        imei = filename[-15:]
        print("IMEI:", imei)
        table_name = (
            table_name.replace(" ", "")
                      .replace("-", "")
                      .replace("+", "_")
                      .replace("_", "")
                      .replace("(", "_")
                      .replace(")", "")
                      .replace(".", "")
        )
        table_name_with_imei = f"{table_name}_{imei}"
        excel_file_path = os.path.join(output_directory, file_name)
        column_names = ['Vehicle', 'Date', 'Time', 'IGN', 'Battery %', 'External Voltage', "Location", "Speed",
                            "Last Distance (meters)", "Distance", "History Data", "No Of Satellite", "Coordinates"]
        df = pd.read_excel(excel_file_path, skiprows=5, names=column_names)
        df['IMEI'] = imei
        df["date_time"] = df["Date"] + " " + df["Time"]

        df.drop(columns=["Date", "Time"], inplace=True)
        df['date_time'] = pd.to_datetime(df['date_time'], format='%d-%m-%Y %H:%M:%S')
        df = df[['IMEI','Vehicle', 'date_time', 'IGN', 'Battery %', 'External Voltage', 'Location', 'Speed',
                     'Last Distance (meters)', 'Distance', 'History Data', 'No Of Satellite', 'Coordinates']]
        
        if df.empty:
            # Create an empty DataFrame with the IMEI value in the first row
            empty_df = pd.DataFrame(columns=df.columns)
            empty_df.loc[0] = [imei] + ['NA'] * (len(df.columns) - 1)
            empty_df.to_sql(table_name, mysql_engine, if_exists='append', index=False)
        else:
            df.to_sql(table_name, mysql_engine, if_exists='append', index=False)
        print(f"Data from {file_name} has been stored in the {table_name} table.")
# Out:
# whiteactiva
# IMEI: whiteactiva
# Data from whiteactiva_355172104292980.xlsx has been stored in the whiteactiva table.

# %%
import sqlalchemy
import pandas as pd
db_username = 'admin'
db_password = 'ingo1234'
db_host = 'database-1.cbjabnlglbz6.ap-south-1.rds.amazonaws.com'
db_name = 'ingodata'
engine = sqlalchemy.create_engine(f"mysql://{db_username}:{db_password}@{db_host}/{db_name}")

# Query the table names
query = "SELECT table_name FROM information_schema.tables WHERE table_schema = :db_name"
table_names = engine.execute(sqlalchemy.text(query), db_name=db_name)
# Query and print the table names
query = "SHOW TABLES"
result = engine.execute(sqlalchemy.text(query))

table_names = [row[0] for row in result]

# Print the list of table names
existing_imeis = {}
for table_index in table_names:
    existing_imeis[table_index] = set(pd.read_sql(f"SELECT IMEI FROM {table_index}", con=engine)['IMEI'])
existing_imeis
# Out:
# {'2seater0229357544375160229': {'357544375160229'},
#  'activablue355172104172638': {'355172104172638'},
#  'b1001blackredv5_allsaintsstore355172102799689': {'355172102799689'},
#  'b1002blueorangev5_youdeemerchandising35517210279990': {'355172102799903'},
#  'b1003blackredv5_rajkamalscreation355172102798459': {'355172102798459'},
#  'b1004blueorangev5_youdeemerchandising3551721027999': {'355172102799911'},
#  'b1005blueorangev5_trivenienterprises355172102798616': {'355172102798616'},
#  'b1006blueorangev5_panchsheelapharma355172102800016': {'355172102800016'},
#  'b1007blackredgray355172102796818': {'355172102796818'},
#  'b1008blackredgrayv5355172102798533': {'355172102798533'},
#  'b1009blackredgray_jagadurumarketing355172102798442': {'355172102798442'},
#  'b1010blackredgrayv5_sanseraengineeringlim355172102': {'355172102797477'},
#  'b1011blueorangev5355172102796875': {'355172102796875'},
#  'b1013blueorangev5355172102797402': {'355172102797402'},
# ...

# %%
len(existing_imeis)
# Out:
# 210

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import mysql.connector
import os
import zipfile
import pandas as pd
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')
db_username = 'admin'
db_password = 'ingo1234'
db_host = 'database-1.cbjabnlglbz6.ap-south-1.rds.amazonaws.com'
db_name = 'ingodata'
engine = create_engine(f"mysql+mysqlconnector://{db_username}:{db_password}@{db_host}/{db_name}")
zip_file_path = r"C:\Users\Aparna\Downloads\20-12-2023_707823461.zip"   
folder_path = r"C:\Users\Aparna\Downloads\20-12-2023_707823461"
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(folder_path)
extracted_files = os.listdir(folder_path)
column_names = ['Vehicle', 'Date', 'Time', 'IGN', 'Battery %', 'External Voltage', 'Location', 'Speed', 'Last Distance (meters)', 'Distance', 'History Data', 'No Of Satellite', 'Coordinates']
for filename in os.listdir(folder_path):
    if filename.endswith('.xlsx'):
        filepath = "".join(filename.split("_")[:-1])
        imei = filepath[-15:]
        found = False
        for table_index in table_names:
            if imei in existing_imeis[table_index]:
                found = True
                column_names = ['Vehicle', 'Date', 'Time', 'IGN', 'Battery %', 'External Voltage', "Location", "Speed","Last Distance (meters)", "Distance", "History Data", "No Of Satellite", "Coordinates"]
                df = pd.read_excel(os.path.join(folder_path, filename), skiprows=5, names=column_names)
                df
                df["date_time"] = df["Date"] + " " + df["Time"]
                df.drop(columns=["Date", "Time"], inplace=True)
                df['IMEI'] = imei
                df['date_time'] = pd.to_datetime(df['date_time'], format='%d-%m-%Y %H:%M:%S')
                df = df[['IMEI', 'Vehicle', 'date_time', 'IGN', 'Battery %', 'External Voltage', 'Location', 'Speed', 'Last Distance (meters)', 'Distance', 'History Data', 'No Of Satellite', 'Coordinates']]
                new_data = df.sort_values(by='date_time')
                new_data = new_data.reset_index(drop=True)
                new_data.to_sql(name=table_index, con=engine, if_exists='append', index=False)
                print(f"Data stored successfully in table {table_index}")
                break 
        if not found:
            print(f"IMEI {imei} was not found in any table.")
# Out:
# Data stored successfully in table 2seater0229357544375160229
# Data stored successfully in table activablue355172104172638
# Data stored successfully in table b1001blackredv5_allsaintsstore355172102799689
# Data stored successfully in table b1002blueorangev5_youdeemerchandising35517210279990
# Data stored successfully in table b1003blackredv5_rajkamalscreation355172102798459
# Data stored successfully in table b1004blueorangev5_youdeemerchandising3551721027999
# Data stored successfully in table b1005blueorangev5_trivenienterprises355172102798616
# Data stored successfully in table b1006blueorangev5_panchsheelapharma355172102800016
# Data stored successfully in table b1007blackredgray355172102796818
# Data stored successfully in table b1008blackredgrayv5355172102798533
# Data stored successfully in table b1009blackredgray_jagadurumarketing355172102798442
# Data stored successfully in table b1010blackredgrayv5_sanseraengineeringlim355172102
# ...

# %%
import pandas as pd

# Read Excel file into a pandas DataFrame
excel_file_path = r'C:\Users\Aparna\Downloads\Travel_Summary_27-02-2024_10-08-32_AM.xlsx'
df = pd.read_excel(excel_file_path)

df.to_csv(r'C:\Users\Aparna\Downloads\Travel_Summary_27-02-2024_10-08-32_AM.csv')
